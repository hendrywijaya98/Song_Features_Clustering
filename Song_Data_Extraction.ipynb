# %% [markdown]
# # import library
# instalasi package spotify

# %% [markdown]
# import library

# %%
# package spotify
import spotipy
from spotipy.oauth2 import SpotifyClientCredentials #To access authorised Spotify data
# untuk mengatur data
import pandas as pd

# %% [markdown]
# masukan client id dan secret key

# %%
client_id = 'insert your client id'
client_secret = 'insert your client password'

client_credentials_manager = SpotifyClientCredentials(client_id=client_id, 
                                                    client_secret=client_secret)
# spotify object to access API
sp = spotipy.Spotify(client_credentials_manager=client_credentials_manager)

# %% [markdown]
# buat function untuk menarik data dari playlist
# - karena default dari user_playlist_track maximal 100
# - function ini berguna agar bisa menarik data lebih dari 100

# %%
def get_playlist_tracks(username,playlist_id):
    results = sp.user_playlist_tracks(username,playlist_id)
    tracks = results['items']
    while results['next']:
        results = sp.next(results)
        tracks.extend(results['items'])
    return tracks

# %% [markdown]
# # lagu - lagu indonesia
# data - data lagu indonesia yang merupakan 200 lagu top berdasarkan [spotifycharts.com](https://spotifycharts.com/)

# %%
indo_song = get_playlist_tracks(
                        username='spotify:user:31qtchl67fq4kmamjicjgukyecfy', 
                        playlist_id='spotify:playlist:080nMYHaJGaaxbpllwq8UP')

# %% [markdown]
# buat dict kosong
#
# kemudian di isi dengan key value nya

# %%
dict_indo = {}
dict_indo['name'] = []
dict_indo['artist'] = []
dict_indo['uri'] = []
dict_indo['key'] = []
dict_indo['mode'] = []
dict_indo['acousticness'] = []
dict_indo['danceability'] = []
dict_indo['energy'] = []
dict_indo['liveness'] = []
dict_indo['loudness'] = []
dict_indo['tempo'] = []
dict_indo['valence'] = []
dict_indo['popularity'] = []

# %% [markdown]
# tarik data dari playlist top 200 indonesia

# %%
for i in indo_song:
    print(i['track']['name'])
    try:
        features = sp.audio_features(i['track']['uri'])
    except:
        print(i['track']['uri'])
        print('skipped')
        continue
    dict_indo['name'].append(i['track']['name'])
    dict_indo['artist'].append(i['track']['artists'][0]['name'])
    dict_indo['uri'].append(i['track']['uri'])
    dict_indo['key'].append(features[0]['key'])
    dict_indo['mode'].append(features[0]['mode'])
    dict_indo['acousticness'].append(features[0]['acousticness'])
    dict_indo['danceability'].append(features[0]['danceability'])
    dict_indo['energy'].append(features[0]['energy'])
    dict_indo['liveness'].append(features[0]['liveness'])
    dict_indo['loudness'].append(features[0]['loudness'])
    dict_indo['tempo'].append(features[0]['tempo'])
    dict_indo['valence'].append(features[0]['valence'])
    dict_indo['popularity'].append(i['track']['popularity'])
# Out:
# On The Ground
# Bertaut
# To the Bone
# Blue Jeans
# Heartbreak Anniversary
# At My Worst
# Leave The Door Open
# Melukis Senja
# Putus Atau Terus
# Gone
# drivers license
# happy
# Weak
# Peaches (feat. Daniel Caesar & Giveon)
# One Only
# Yours
# I Just Couldn't Save You Tonight (feat. Aurélie) - Story of Kale - Original Motion Picture Soundtrack
# Mungkin Hari Ini Esok Atau Nanti
# Kenangan Manis
# Hold On
# Heather
# After School
# Snowman
# Monolog
# Kota
# I Love You but I'm Letting Go
# Celebrity
# Lantas
# Rumah Ke Rumah
# Makna Cinta
# C.H.R.I.S.Y.E.
# Katakan Saja
# Lose
# Before You Go
# Maafkan Aku #terlanjurmencinta
# 34+35
# positions
# Sudah - Story of Kale - Original Motion Picture Soundtrack
# Life Goes On
# Hurts So Good
# Bahasa Kalbu
# Stuck with U (with Justin Bieber)
# Dynamite
# LILAC
# Resah Jadi Luka
# Kukira Kau Rumah
# I'm Missing You
# Into Your Arms (feat. Ava Max)
# Belum Siap Kehilangan
# Cuek
# if u could see me cryin' in my room
# Secukupnya
# ...

# %%
indo_song[1]['track']['artists']
# Out:
# [{'external_urls': {'spotify': 'https://open.spotify.com/artist/20zafXaLhm5IcXnSU93rNn'},
#   'href': 'https://api.spotify.com/v1/artists/20zafXaLhm5IcXnSU93rNn',
#   'id': '20zafXaLhm5IcXnSU93rNn',
#   'name': 'Nadin Amizah',
#   'type': 'artist',
#   'uri': 'spotify:artist:20zafXaLhm5IcXnSU93rNn'}]

# %% [markdown]
# masukan dictionary lagu indo ke dataframe

# %%
import pandas as pd

df_indosong = pd.DataFrame(dict_indo)
df_indosong
# Out:
#                        name         artist  \
# 0             On The Ground           ROSÉ
# 1                   Bertaut   Nadin Amizah
# 2               To the Bone      Pamungkas
# 3                Blue Jeans         GANGGA
# 4    Heartbreak Anniversary         Giveon
# ..                      ...            ...
# 195                 Forever         GANGGA
# 196    lovely (with Khalid)  Billie Eilish
# 197            Pilu Membiru      Kunto Aji
# 198             Ruang Rindu          Letto
# 199         Takkan Terganti        Marcell
#
#                                       uri  key  mode  acousticness  \
# 0    spotify:track:2pn8dNVSpYnAtlKFC8Q0DJ    1     1        0.0174
# 1    spotify:track:630DpnzdfjdVqv2yLfPbAX    6     1        0.9330
# 2    spotify:track:3pCt2wRdBDa2kCisIdHWgF    7     0        0.5140
# 3    spotify:track:4kfjA6WfgKBt7I7YKuDCkU    7     1        0.9380
# 4    spotify:track:3FAJ6O0NOHQV8Mc5Ri6ENp    0     1        0.5240
# ...

# %% [markdown]
# mengurutkan popularity secara descending, dan menghapus duplikasi, kemudian diurutkan berdasarkan index

# %%
lagu_indo = df_indosong.sort_values('popularity', ascending=False).drop_duplicates('name').sort_index()
lagu_indo
# Out:
#                        name         artist  \
# 0             On The Ground           ROSÉ
# 1                   Bertaut   Nadin Amizah
# 2               To the Bone      Pamungkas
# 3                Blue Jeans         GANGGA
# 4    Heartbreak Anniversary         Giveon
# ..                      ...            ...
# 195                 Forever         GANGGA
# 196    lovely (with Khalid)  Billie Eilish
# 197            Pilu Membiru      Kunto Aji
# 198             Ruang Rindu          Letto
# 199         Takkan Terganti        Marcell
#
#                                       uri  key  mode  acousticness  \
# 0    spotify:track:2pn8dNVSpYnAtlKFC8Q0DJ    1     1        0.0174
# 1    spotify:track:630DpnzdfjdVqv2yLfPbAX    6     1        0.9330
# 2    spotify:track:3pCt2wRdBDa2kCisIdHWgF    7     0        0.5140
# 3    spotify:track:4kfjA6WfgKBt7I7YKuDCkU    7     1        0.9380
# 4    spotify:track:3FAJ6O0NOHQV8Mc5Ri6ENp    0     1        0.5240
# ...

# %%
lagu_indo.sort_values('liveness', ascending = False)
# Out:
#                               name         artist  \
# 150                  Mad at Disney    salem ilese
# 70                       Good Days            SZA
# 124                       comethru  Jeremy Zucker
# 103                Save Your Tears     The Weeknd
# 102       LATHI (with Sara Fajira)   Weird Genius
# ..                             ...            ...
# 21                    After School        Weeekly
# 120              How You Like That      BLACKPINK
# 160              Kenangan Terindah        SAMSONS
# 146                           Fine        TAEYEON
# 144  Ice Cream (with Selena Gomez)      BLACKPINK
#
#                                       uri  key  mode  acousticness  \
# 150  spotify:track:7aGyRfJWtLqgJaZoG9lJhE    0     1       0.42400
# 70   spotify:track:3YJJjQPAbDT7mGpX3WtQ9A    1     0       0.49900
# 124  spotify:track:18uwL0vNUanqZH0ro2QcOP    0     1       0.60700
# 103  spotify:track:5QO79kh1waicV47BqGRL3g    0     1       0.02120
# ...

# %% [markdown]
# ### Extract History
# 1. Extract Top Indonesia 200 Spotify song Weekly `at 07/04/2021`

# %% [markdown]
# cek baris dan kolomnya

# %%
print(f'Ukuran Dataset : {lagu_indo.shape[0]} Baris dan {lagu_indo.shape[1]} Kolom')
# Out:
# Ukuran Dataset : 200 Baris dan 13 Kolom

# %% [markdown]
# masukan ke csv

# %%
lagu_indo.to_csv('lagu_indo.csv', index=False)

# %% [markdown]
# # lagu - lagu jpop

# %%
jpop_song = get_playlist_tracks(username='spotify:user:31qtchl67fq4kmamjicjgukyecfy', playlist_id='spotify:playlist:1NtmPbISQMJtXSdSK1cTku')

# %% [markdown]
# buat dict kosong
#
# kemudian di isi dengan key value nya

# %%
dict_jpop = {}
dict_jpop['name'] = []
dict_jpop['artist'] = []
dict_jpop['uri'] = []
dict_jpop['key'] = []
dict_jpop['mode'] = []
dict_jpop['acousticness'] = []
dict_jpop['danceability'] = []
dict_jpop['energy'] = []
dict_jpop['liveness'] = []
dict_jpop['loudness'] = []
dict_jpop['tempo'] = []
dict_jpop['valence'] = []
dict_jpop['popularity'] = []

# %% [markdown]
# tarik data dari playlist lagu jpop

# %%
for i in jpop_song:
    print(i['track']['name'])
    try:
        features = sp.audio_features(i['track']['uri'])
    except:
        print(i['track']['uri'])
        print('skipped')
        continue
    dict_jpop['name'].append(i['track']['name'])
    dict_jpop['artist'].append(i['track']['artists'][0]['name'])
    dict_jpop['uri'].append(i['track']['uri'])
    dict_jpop['key'].append(features[0]['key'])
    dict_jpop['mode'].append(features[0]['mode'])
    dict_jpop['acousticness'].append(features[0]['acousticness'])
    dict_jpop['danceability'].append(features[0]['danceability'])
    dict_jpop['energy'].append(features[0]['energy'])
    dict_jpop['liveness'].append(features[0]['liveness'])
    dict_jpop['loudness'].append(features[0]['loudness'])
    dict_jpop['tempo'].append(features[0]['tempo'])
    dict_jpop['valence'].append(features[0]['valence'])
    dict_jpop['popularity'].append(i['track']['popularity'])

# %%
jpop_song[1]['track']['artists']
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-29-4999ad1d58df> in <module>
# ----> 1 jpop_song[1]['track']['artists']
#
# IndexError: list index out of range

# %% [markdown]
# masukan dictionary lagu indo ke dataframe

# %%
df_jpopsong = pd.DataFrame(dict_jpop)
df_jpopsong

# %% [markdown]
# mengurutkan popularity secara descending, dan menghapus duplikasi, kemudian diurutkan berdasarkan index

# %%
lagu_jpop = df_jpopsong.sort_values('popularity', ascending=False).drop_duplicates('name').sort_index()
lagu_jpop

# %% [markdown]
# cek baris dan kolomnya

# %%
print(f'Ukuran Dataset : {lagu_jpop.shape[0]} Baris dan {lagu_jpop.shape[1]} Kolom')

# %% [markdown]
# # lagu - lagu jkt48
# mengekstrak berdasarkan nama artis

# %%
# query buat pencarian
result = sp.search('JKT48')
# tampilkan dengan label track dan items
result['tracks']['items'][0]['artists']
# Out:
# [{'external_urls': {'spotify': 'https://open.spotify.com/artist/2l8I5pWUnfF7bMK1z6EJRk'},
#   'href': 'https://api.spotify.com/v1/artists/2l8I5pWUnfF7bMK1z6EJRk',
#   'id': '2l8I5pWUnfF7bMK1z6EJRk',
#   'name': 'JKT48',
#   'type': 'artist',
#   'uri': 'spotify:artist:2l8I5pWUnfF7bMK1z6EJRk'}]

# %% [markdown]
# ekstrak uri artisnya
#
# kemudian tarik data pada album artisnya

# %%
# extract  uri pada artisnya
artist_uri = result['tracks']['items'][0]['artists'][0]['uri']
# tarik semua album pada artisnya 
sp_albums = sp.artist_albums(artist_uri)

# %% [markdown]
# setelah di extract albumnya
#
# taro masing - masing nama ama uri nya ke list kosong, karena mengambil daftar lagu dengan perulangan

# %%
# buat list kosong buat nampung nama album artis sama uri nya
album_names = []
album_uris = []

# tarik lagu dengan perulangan, dimana i mengakses setiap item lagu pada album
for i in range(len(sp_albums['items'])):
    album_names.append(sp_albums['items'][i]['name'])
    album_uris.append(sp_albums['items'][i]['uri'])
    
album_names
album_uris
# Out:
# ['spotify:album:2qNMxEpVKiQL9jvIh9vQ3N',
#  'spotify:album:4WDkgckiwophdVuPJU3urn',
#  'spotify:album:4ldcxoIPb8bsidHH3qutMV',
#  'spotify:album:3F0dZdnaUtMDdSjyhn8Ks6',
#  'spotify:album:5cL1vy3oeuo59haPxS0OGf',
#  'spotify:album:7EOQMtwLLmDPt5eYSzkh8J',
#  'spotify:album:4emaCTwP0b0p35O4PHz73r',
#  'spotify:album:709YDFC9T1I6jlch7l5vUF',
#  'spotify:album:4odaecgN8u8j8GYtKqqoFz',
#  'spotify:album:77tB7zZBhDAu0g03YqLi86',
#  'spotify:album:2N6BEEodE5oqDj0cgPgLbk',
#  'spotify:album:0UJgEYfBloQWig4EpBGJYI',
#  'spotify:album:12jouL3ts613yYVRHMf0Ci',
#  'spotify:album:2eIwOfkebJHjEIpJZ5Txvu',
#  'spotify:album:0FiXJC94RTKMPRxJdZamC0',
#  'spotify:album:1qNdDlHmQRjiBlpJFqByUj',
#  'spotify:album:6gvebFYL5Wt2i0LEoNSyPW',
#  'spotify:album:02ECGWaPjemLbarmHlPoge',
#  'spotify:album:4X9gRVjLJhpsZLKDI8AMGN',
#  'spotify:album:5CwGJzh8jGQSwBr0PEUkNY']

# %% [markdown]
# ## ambil data lagu dari tiap album
# menggunakan looping dengan index yang mengakes tiap album buat mengekstrak key pada data track albumnya

# %%
# diakses dengan uri
def albumSongs(uri):
    # assign album uri ke nama album
    album = uri 
    # buat dictionary koosong buat nentuin albumnya 
    # buat key value biar dimasukin ke dictionary albumnya
    spotify_albums[album] = {} 
    # bikin list kosong
    spotify_albums[album]['album'] = []
    spotify_albums[album]['track_number'] = []
    spotify_albums[album]['id'] = []
    spotify_albums[album]['name'] = []
    spotify_albums[album]['uri'] = []
    # narik data dari track album
    tracks = sp.album_tracks(album) 
    # pengulangan buat tiap lagunya 
    for n in range(len(tracks['items'])): 
        # nambahin nama album yang di track pake album_count
        spotify_albums[album]['album'].append(album_names[album_count]) 
        spotify_albums[album]['track_number'].append(tracks['items'][n]['track_number'])
        spotify_albums[album]['id'].append(tracks['items'][n]['id'])
        spotify_albums[album]['name'].append(tracks['items'][n]['name'])
        spotify_albums[album]['uri'].append(tracks['items'][n]['uri'])

# %% [markdown]
# trus jalanin function ke tiap album uri ke list buat narik datanya
#
# trus ditampung ke dict kosong buat nampung data albumnya

# %%
spotify_albums = {}
album_count = 0
for i in album_uris: #each album
    albumSongs(i)
    print("Album " + str(album_names[album_count]) + " songs has been added to spotify_albums dictionary")
    album_count+=1 #Updates album count once all tracks have been added
# Out:
# Album Sambil Menggandeng Erat Tanganku (Te Wo Tsunaginagara) songs has been added to spotify_albums dictionary
# Album Tadaima Renaichuu (Sekarang Sedang Jatuh Cinta) songs has been added to spotify_albums dictionary
# Album Theater No Megami - Dewi Theater songs has been added to spotify_albums dictionary
# Album Saishuu Bell Ga Naru - Bel Terakhir Berbunyi (Live) songs has been added to spotify_albums dictionary
# Album Seishun Girls - Gadis Gadis Remaja songs has been added to spotify_albums dictionary
# Album Dareka No Tame Ni - Demi Seseorang songs has been added to spotify_albums dictionary
# Album Pajama Drive songs has been added to spotify_albums dictionary
# Album Joy Kick! Tears songs has been added to spotify_albums dictionary
# Album B.E.L.I.E.V.E songs has been added to spotify_albums dictionary
# Album Mahagita - Kamikyokutachi songs has been added to spotify_albums dictionary
# Album Boku No Taiyou (Matahari Milikku) songs has been added to spotify_albums dictionary
# ...

# %% [markdown]
# ## Grab fitur audio buat tiap lagu
# bkin key values buat nampung fitur atau variabel kolom pada tiap track album
#
# trus tambahin ke list yang merupakan representasi semua track musik pada album

# %%
def audio_features(album):
    #Add new key-values to store audio features
    spotify_albums[album]['key'] = []
    spotify_albums[album]['mode'] = []
    spotify_albums[album]['acousticness'] = []
    spotify_albums[album]['danceability'] = []
    spotify_albums[album]['energy'] = []
    spotify_albums[album]['liveness'] = []
    spotify_albums[album]['loudness'] = []
    spotify_albums[album]['tempo'] = []
    spotify_albums[album]['valence'] = []
    spotify_albums[album]['popularity'] = []

    # bikin track counter buat variabel inisiasi pada perulangan
    track_count = 0
    for track in spotify_albums[album]['uri']:
        # tarik fitur audio per track
        print("Requesting " + track)
        features = sp.audio_features(track)
        
        # masukin ke key value yang sesuai
        spotify_albums[album]['key'].append(features[0]['key'])
        spotify_albums[album]['mode'].append(features[0]['mode'])
        spotify_albums[album]['acousticness'].append(features[0]['acousticness'])
        spotify_albums[album]['danceability'].append(features[0]['danceability'])
        spotify_albums[album]['energy'].append(features[0]['energy'])
        spotify_albums[album]['liveness'].append(features[0]['liveness'])
        spotify_albums[album]['loudness'].append(features[0]['loudness'])
        spotify_albums[album]['tempo'].append(features[0]['tempo'])
        spotify_albums[album]['valence'].append(features[0]['valence'])
        # popularitas juga ditampung
        pop = sp.track(track)
        spotify_albums[album]['popularity'].append(pop['popularity'])
        track_count+=1

# %% [markdown]
# ### looping pada album untuk mengekstrak fitur audio nya

# %%
import time
import numpy as np
sleep_min = 2
sleep_max = 5
start_time = time.time()
request_count = 0
for i in spotify_albums:
    audio_features(i)
    request_count+=1
    if request_count % 5 == 0:
        print(str(request_count) + " playlists completed")
        time.sleep(np.random.uniform(sleep_min, sleep_max))
        print('Loop #: {}'.format(request_count))
        print('Elapsed Time: {} seconds'.format(time.time() - start_time))
# Out:
# Requesting spotify:track:6U414whZIjUemv2PJlA8Gn
# Requesting spotify:track:31nieaEysYbsLAvgB4fDne
# Requesting spotify:track:6U3QGoLEtd6ZQCRvcDC5ec
# Requesting spotify:track:3IUgZDqcJCFF8Ftgjk9Tfm
# Requesting spotify:track:2b3FgkzrZBlBqtXxTICGnl
# Requesting spotify:track:6EOyaS6ybPa7Ajk69QWohm
# Requesting spotify:track:06yIPZ63NzeJKQQiohIKGC
# Requesting spotify:track:1PbZJM1HwpZb11zQzXsPIX
# Requesting spotify:track:38wRbV0hVgqKEdVJvf2spj
# Requesting spotify:track:1Ap6Z4YuV4w5OR7WppqtoZ
# Requesting spotify:track:3YoRmzVREKTCDgglWsHcyq
# Requesting spotify:track:3ru42XalRdAtwa6oMeBXfG
# Requesting spotify:track:0qp57heMiNVHJ5OQTgDECt
# Requesting spotify:track:5isR6Ylx60ZpaKZHtz0MYZ
# Requesting spotify:track:1sVZeoS1STol1rr1TW4Xjl
# Requesting spotify:track:5mrimjAzZOxDS3r3gycAFM
# Requesting spotify:track:6VPzrHarUM4kwkqaFIBFnV
# Requesting spotify:track:73cKAzrIdgN4nfcEdf21LI
# Requesting spotify:track:3zJU9WtAAjQx16JiuLSK9A
# Requesting spotify:track:0EW61yQaKTxueI3Rjr015G
# ...

# %% [markdown]
# ## masukin data ke tabel dataframe

# %%
dic_jkt = {}
dic_jkt['album'] = []
dic_jkt['track_number'] = []
dic_jkt['id'] = []
dic_jkt['name'] = []
dic_jkt['uri'] = []
dic_jkt['key'] = []
dic_jkt['mode'] = []
dic_jkt['danceability'] = []
dic_jkt['acousticness'] = []
dic_jkt['energy'] = []
dic_jkt['liveness'] = []
dic_jkt['loudness'] = []
dic_jkt['tempo'] = []
dic_jkt['valence'] = []
dic_jkt['popularity'] = []
for album in spotify_albums: 
    for feature in spotify_albums[album]:
        dic_jkt[feature].extend(spotify_albums[album][feature])
        
len(dic_jkt['album'])
# Out:
# 218

# %% [markdown]
# masukin ke dataframe

# %%
df_jkt = pd.DataFrame.from_dict(dic_jkt)
df_jkt.head(20)
# Out:
#                                                 album  track_number  \
# 0   Sambil Menggandeng Erat Tanganku (Te Wo Tsunag...             1
# 1   Sambil Menggandeng Erat Tanganku (Te Wo Tsunag...             2
# 2   Sambil Menggandeng Erat Tanganku (Te Wo Tsunag...             3
# 3   Sambil Menggandeng Erat Tanganku (Te Wo Tsunag...             4
# 4   Sambil Menggandeng Erat Tanganku (Te Wo Tsunag...             5
# 5   Sambil Menggandeng Erat Tanganku (Te Wo Tsunag...             6
# 6   Sambil Menggandeng Erat Tanganku (Te Wo Tsunag...             7
# 7   Sambil Menggandeng Erat Tanganku (Te Wo Tsunag...             8
# 8   Sambil Menggandeng Erat Tanganku (Te Wo Tsunag...             9
# 9   Sambil Menggandeng Erat Tanganku (Te Wo Tsunag...            10
# 10  Sambil Menggandeng Erat Tanganku (Te Wo Tsunag...            11
# 11  Sambil Menggandeng Erat Tanganku (Te Wo Tsunag...            12
# 12  Sambil Menggandeng Erat Tanganku (Te Wo Tsunag...            13
# ...

# %% [markdown]
# buat dataframe finalnya
#
# dengan mengurutkan berdasarkan popularitas dan menghapus duplikasinya

# %%
lagu_jkt48 = df_jkt.sort_values('popularity', ascending=False).drop_duplicates('name').sort_index()
lagu_jkt48.shape
# Out:
# (199, 15)

# %% [markdown]
# ## Export Lagu JKT48 ke CSV

# %%
lagu_jkt48.to_csv('lagu_jkt48.csv', index=False)

# %% [markdown]
# # lagu - lagu kpop

# %% [markdown]
# scrapt data dari [Playlist "K-Pop Hits 2021"](https://open.spotify.com/playlist/4QXgG8a9KkUzaNpHS98G0O) pada user [Filtr Éxitosp](https://open.spotify.com/user/mejoresplaylistsspotify) dan [Playlist "TOP 100 KPOP Songs 2021"](https://open.spotify.com/playlist/5Di5zq6FdHlrRdcqJxfVmA) pada user [David Li](https://open.spotify.com/user/1158834068)

# %%
# lagu Kpop dari Playlist "K-Pop Hits 2021" pada user Filtr Éxitosp
kpop1_song = get_playlist_tracks(
                        username='spotify:user:mejoresplaylistsspotify', 
                        playlist_id='spotify:playlist:4QXgG8a9KkUzaNpHS98G0O')

# lagu Kpop dari Playlist "TOP 100 KPOP Songs 2021" pada user David Li
kpop2_song = get_playlist_tracks(
                        username='spotify:user:1158834068', 
                        playlist_id='spotify:playlist:5Di5zq6FdHlrRdcqJxfVmA')

# %% [markdown]
# buat dict kosong
#
# kemudian di isi dengan key value nya

# %%
# dict untuk playlist kpop pertama
dict_kpop1 = {}
dict_kpop1['name'] = []
dict_kpop1['artist'] = []
dict_kpop1['uri'] = []
dict_kpop1['key'] = []
dict_kpop1['mode'] = []
dict_kpop1['acousticness'] = []
dict_kpop1['danceability'] = []
dict_kpop1['energy'] = []
dict_kpop1['liveness'] = []
dict_kpop1['loudness'] = []
dict_kpop1['tempo'] = []
dict_kpop1['valence'] = []
dict_kpop1['popularity'] = []

# dict untuk playlist kpop kedua
dict_kpop2 = {}
dict_kpop2['name'] = []
dict_kpop2['artist'] = []
dict_kpop2['uri'] = []
dict_kpop2['key'] = []
dict_kpop2['mode'] = []
dict_kpop2['acousticness'] = []
dict_kpop2['danceability'] = []
dict_kpop2['energy'] = []
dict_kpop2['liveness'] = []
dict_kpop2['loudness'] = []
dict_kpop2['tempo'] = []
dict_kpop2['valence'] = []
dict_kpop2['popularity'] = []

# %% [markdown]
# tarik data dari playlist lagu kpop yang pertama

# %%
for i in kpop1_song:
    print(i['track']['name'])
    try:
        features = sp.audio_features(i['track']['uri'])
    except:
        print(i['track']['uri'])
        print('skipped')
        continue
    dict_kpop1['name'].append(i['track']['name'])
    dict_kpop1['artist'].append(i['track']['artists'][0]['name'])
    dict_kpop1['uri'].append(i['track']['uri'])
    dict_kpop1['key'].append(features[0]['key'])
    dict_kpop1['mode'].append(features[0]['mode'])
    dict_kpop1['acousticness'].append(features[0]['acousticness'])
    dict_kpop1['danceability'].append(features[0]['danceability'])
    dict_kpop1['energy'].append(features[0]['energy'])
    dict_kpop1['liveness'].append(features[0]['liveness'])
    dict_kpop1['loudness'].append(features[0]['loudness'])
    dict_kpop1['tempo'].append(features[0]['tempo'])
    dict_kpop1['valence'].append(features[0]['valence'])
    dict_kpop1['popularity'].append(i['track']['popularity'])
# Out:
# Butter
# Deja Vu
# Permission to Dance
# Dun Dun Dance
# Antidote
# Fireworks (I'm The One)
# Butter (feat. Megan Thee Stallion)
# In the morning
# Super Summer
# Dynamite
# Like It Hot
# You make Me
# PARANOIA
# TAIL
# Life Goes On
# Popping
# STALKER
# Going Dumb (with Stray Kids)
# Playlist (feat. Jiselle)
# INCEPTION
# LOVE% (feat. DAWN)
# Runner (feat. CHANGMO)
# YOU
# Boy With Luv (feat. Halsey)
# Lovesick Girls
# The Leaders
# Waves (feat. Simon Dominic & Jamie)
# Savage Love (Laxed – Siren Beat) [BTS Remix]
# 蹦
# YES
# DI SINI
# Time Of Love
# EXIT
# What You Waiting For
# Don't follow me
# HOLO
# Take Me Home - English Version
# Goblin (Favorite Boys)
# How You Like That
# DRUM (New)
# Celebrate
# Answer
# LOST IN PARADISE
# Take Me Home
# Ready Or Not
# How You Like That
# God’s Menu
# WANNABE
# Fly To My Room
# FANTASIA
# ON (Feat. Sia)
# I'm The One - HEAT-TOPPING Version
# Facetime, Face me
# A few miles (feat. Jiselle)
# Make you happy
# Monster
# ...

# %% [markdown]
# tarik data dari playlist lagu kpop yang kedua

# %%
for i in kpop2_song:
    print(i['track']['name'])
    try:
        features = sp.audio_features(i['track']['uri'])
    except:
        print(i['track']['uri'])
        print('skipped')
        continue
    dict_kpop2['name'].append(i['track']['name'])
    dict_kpop2['artist'].append(i['track']['artists'][0]['name'])
    dict_kpop2['uri'].append(i['track']['uri'])
    dict_kpop2['key'].append(features[0]['key'])
    dict_kpop2['mode'].append(features[0]['mode'])
    dict_kpop2['acousticness'].append(features[0]['acousticness'])
    dict_kpop2['danceability'].append(features[0]['danceability'])
    dict_kpop2['energy'].append(features[0]['energy'])
    dict_kpop2['liveness'].append(features[0]['liveness'])
    dict_kpop2['loudness'].append(features[0]['loudness'])
    dict_kpop2['tempo'].append(features[0]['tempo'])
    dict_kpop2['valence'].append(features[0]['valence'])
    dict_kpop2['popularity'].append(i['track']['popularity'])
# Out:
# RECIPE
# Promise (I'll be)
# no shadow
# Perfect Man
# Yes No Maybe
# Zombie High
# Day Star
# Penthouse (Prod. APRO)
# Francesca
# Wang Like Alexander
# Potion
# Honestly
# Person Like A Person
# Leave
# The open boat
# 달리
# You Back Then (feat. Jayeong Seo)
# Come Over
# Stay Here
# O.M.G.
# Voice 묵소리
# Intro: Singularity
# Jasmine
# DDU-DU DDU-DU
# Boong-Boong
# ALARM
# POOL
# SHE BAD
# Get It
# Remind you
# Penalty
# Way Back Home
# Go Deep
# RUN
# Take Me Higher
# I'll Find You (feat. June)
# DIFFERENT
# Choppy
# My Pace
# KILLING ME
# I’m Good
# Cereal
# Your Night
# My Paradise
# XIBAL
# V
# Tempo
# COCO BOTTLE
# NOAH
# One of Those Nights
# 나의 땅
# ADDICT
# FIRE
# Tequila (feat. Hoody)
# ENGINE
# MIROH
# Kill This Love
# Bon Bon Chocolat
# OVERZONE
# Valkyrie
# MILLION
# We Go Up
# Super Asia
# 9 and Three Quarters (Run Away)
# Jopping
# 2 Fast
# Runaway
# TMI
# Right away
# 119 REMIX
# Wet The Bed
# Transcend
# Wifey
# Psycho
# Too Much
# You Can Try 해도 돼
# HIP
# ...

# %% [markdown]
# masukan dictionary lagu kpop dari playlist pertama ke dataframe

# %%
import pandas as pd

df_kpop1 = pd.DataFrame(dict_kpop1)
df_kpop1
# Out:
#                       name       artist                                   uri  \
# 0                   Butter          BTS  spotify:track:3VqeTFIvhxu3DIe4eZVzGq
# 1                  Deja Vu        ATEEZ  spotify:track:3zmrdOtnOogqLllz26WLZ3
# 2      Permission to Dance          BTS  spotify:track:0LThjFY2iTtNdd4wviwVV2
# 3            Dun Dun Dance   OH MY GIRL  spotify:track:54HsCR7lJJdwxmEnTY1JfF
# 4                 Antidote  KANG DANIEL  spotify:track:34U33Fr2hM6wWkjvdpiwS6
# ..                     ...          ...                                   ...
# 135  GANG - Official Remix        Sik-K  spotify:track:1s0omF56w0oAEZiWp1VNS7
# 136                 Zombie         DAY6  spotify:track:4s0dJmVknlUl7V6oK3puzZ
# 137               NINETEEN        NATTY  spotify:track:3mVzC9U8eyAmDNWnPniCIN
# 138           Fall in Love     Youngjae  spotify:track:4lpMmdpOCEc2LJVgTFny46
# 139     All The Way Up (K)     Jay Park  spotify:track:6lp2MvqEBSdL3L84GAvl4o
#
# ...

# %% [markdown]
# masukan dictionary lagu kpop dari playlist kedua ke dataframe

# %%
df_kpop2 = pd.DataFrame(dict_kpop2)
df_kpop2
# Out:
#                   name         artist                                   uri  \
# 0               RECIPE          WOODZ  spotify:track:6UgtZqF1ohFKyeRznjI8fP
# 1    Promise (I'll be)            2PM  spotify:track:22gIYvi39amZmTIWimZvCP
# 2            no shadow         Jun. K  spotify:track:6GeBQeUkpLdpbHi1dd7YHa
# 3          Perfect Man        SHINHWA  spotify:track:115a4lQhDJGnu4QVSa8bUW
# 4         Yes No Maybe           Suzy  spotify:track:5agNBfJwMMQKZqpexZJNd8
# ..                 ...            ...                                   ...
# 108        gimme gimme        NCT 127  spotify:track:6shrCEEMcrT6Akxkk8IhLC
# 109        Drunk-Dazed        ENHYPEN  spotify:track:1wcr8DjnN59Awev8nnKpQ4
# 110           Hanryang  Min Kyunghoon  spotify:track:2JHHa7MKQahUQi5d4At1GZ
# 111      Don't Call Me         SHINee  spotify:track:462OPOKW0VMbvW9H7HIb0U
# 112     Teléfono Remix           pH-1  spotify:track:0vZi38VepxZWh0ACqYaXio
#
# ...

# %% [markdown]
# kemudian gabungkan kedua dataframe menjadi satu tabel

# %%
df_kpop = df_kpop1.append(df_kpop2, ignore_index = True)
df_kpop
# Out:
#                     name         artist                                   uri  \
# 0                 Butter            BTS  spotify:track:3VqeTFIvhxu3DIe4eZVzGq
# 1                Deja Vu          ATEEZ  spotify:track:3zmrdOtnOogqLllz26WLZ3
# 2    Permission to Dance            BTS  spotify:track:0LThjFY2iTtNdd4wviwVV2
# 3          Dun Dun Dance     OH MY GIRL  spotify:track:54HsCR7lJJdwxmEnTY1JfF
# 4               Antidote    KANG DANIEL  spotify:track:34U33Fr2hM6wWkjvdpiwS6
# ..                   ...            ...                                   ...
# 248          gimme gimme        NCT 127  spotify:track:6shrCEEMcrT6Akxkk8IhLC
# 249          Drunk-Dazed        ENHYPEN  spotify:track:1wcr8DjnN59Awev8nnKpQ4
# 250             Hanryang  Min Kyunghoon  spotify:track:2JHHa7MKQahUQi5d4At1GZ
# 251        Don't Call Me         SHINee  spotify:track:462OPOKW0VMbvW9H7HIb0U
# 252       Teléfono Remix           pH-1  spotify:track:0vZi38VepxZWh0ACqYaXio
#
# ...

# %% [markdown]
# hapus duplikat yang ada dataframe, diurutkan berdasarkan index

# %%
lagu_kpop = df_kpop.sort_values('popularity', ascending=False).drop_duplicates('name').sort_index()
lagu_kpop
# Out:
#                     name         artist                                   uri  \
# 0                 Butter            BTS  spotify:track:3VqeTFIvhxu3DIe4eZVzGq
# 1                Deja Vu          ATEEZ  spotify:track:3zmrdOtnOogqLllz26WLZ3
# 2    Permission to Dance            BTS  spotify:track:0LThjFY2iTtNdd4wviwVV2
# 3          Dun Dun Dance     OH MY GIRL  spotify:track:54HsCR7lJJdwxmEnTY1JfF
# 4               Antidote    KANG DANIEL  spotify:track:34U33Fr2hM6wWkjvdpiwS6
# ..                   ...            ...                                   ...
# 248          gimme gimme        NCT 127  spotify:track:6shrCEEMcrT6Akxkk8IhLC
# 249          Drunk-Dazed        ENHYPEN  spotify:track:1wcr8DjnN59Awev8nnKpQ4
# 250             Hanryang  Min Kyunghoon  spotify:track:2JHHa7MKQahUQi5d4At1GZ
# 251        Don't Call Me         SHINee  spotify:track:462OPOKW0VMbvW9H7HIb0U
# 252       Teléfono Remix           pH-1  spotify:track:0vZi38VepxZWh0ACqYaXio
#
# ...

# %% [markdown]
# urutkan dengan liveness terbanyak

# %%
lagu_kpop.sort_values('liveness', ascending=False)
# Out:
#                               name      artist  \
# 204                        Jopping      SuperM
# 248                    gimme gimme     NCT 127
# 157                      Come Over        DEAN
# 180                       I’m Good       BUMZU
# 110                    Double Knot  Stray Kids
# ..                             ...         ...
# 103            MIDDLE OF THE NIGHT    Monsta X
# 148                      Francesca   Hash Swan
# 62              pporappippam 보라빛 밤       SUNMI
# 221                     TIME LAPSE   Young Kay
# 63   Ice Cream (with Selena Gomez)   BLACKPINK
#
#                                       uri  key  mode  acousticness  \
# 204  spotify:track:5WrEilrRI5cIW0DxMvQYPZ   10     0        0.0139
# 248  spotify:track:6shrCEEMcrT6Akxkk8IhLC    0     1        0.1070
# 157  spotify:track:1ieDhJfetL1wUFTC0YIriP    6     0        0.0893
# 180  spotify:track:1XU8ZM2uaEzVh3nZHmZfGl    7     1        0.1790
# ...

# %%
lagu_kpop.to_csv('lagu_kpop.csv', index=False)

# %% [markdown]
# # Export Lagu dari Data CSV

# %%
df_laguindo = pd.read_csv('lagu_indo.csv')
df_lagujkt48 = pd.read_csv('lagu_jkt48.csv')

# %%
df_lagujkt48.head(10)
# Out:
#                                                album  track_number  \
# 0  Sambil Menggandeng Erat Tanganku (Te Wo Tsunag...             1
# 1  Sambil Menggandeng Erat Tanganku (Te Wo Tsunag...             2
# 2  Sambil Menggandeng Erat Tanganku (Te Wo Tsunag...             3
# 3  Sambil Menggandeng Erat Tanganku (Te Wo Tsunag...             4
# 4  Sambil Menggandeng Erat Tanganku (Te Wo Tsunag...             5
# 5  Sambil Menggandeng Erat Tanganku (Te Wo Tsunag...             6
# 6  Sambil Menggandeng Erat Tanganku (Te Wo Tsunag...             7
# 7  Sambil Menggandeng Erat Tanganku (Te Wo Tsunag...             8
# 8  Sambil Menggandeng Erat Tanganku (Te Wo Tsunag...             9
# 9  Sambil Menggandeng Erat Tanganku (Te Wo Tsunag...            10
#
#                        id                                               name  \
# 0  6U414whZIjUemv2PJlA8Gn                        Angin Kita - Bokura No Kaze
# ...

# %%
only_today = df_lagujkt48[df_lagujkt48['name'] == 'Only Today']
love_chase = df_lagujkt48[df_lagujkt48['name'] == 'Love Chase']
rapsodi = df_lagujkt48[df_lagujkt48['name'] == 'Rapsodi']
himawari = df_lagujkt48[df_lagujkt48['name'] == 'Himawari - Bunga Matahari']
lantang = df_lagujkt48[df_lagujkt48['name'] == 'Lantang']

# %%
df_lagujkt48['album'].unique()
# Out:
# array(['Sambil Menggandeng Erat Tanganku (Te Wo Tsunaginagara)',
#        'Tadaima Renaichuu (Sekarang Sedang Jatuh Cinta)',
#        'Theater No Megami - Dewi Theater',
#        'Saishuu Bell Ga Naru - Bel Terakhir Berbunyi (Live)',
#        'Seishun Girls - Gadis Gadis Remaja',
#        'Dareka No Tame Ni - Demi Seseorang', 'Pajama Drive',
#        'Joy Kick! Tears', 'B.E.L.I.E.V.E', 'Mahagita - Kamikyokutachi',
#        'Boku No Taiyou (Matahari Milikku)',
#        'Renai Kinshi Jourei (Aturan Anti Cinta)', 'Heavy Rotation',
#        'Bukan PHO (Cover Version)',
#        'Cara Ceroboh untuk Mencinta - Darashinai Aishikata',
#        'JKT48 Acoustic', 'Rapsodi', 'Jkt48 - 5TH Sousenkyo Special Unit',
#        'High Tension'], dtype=object)

# %%
only_today.to_csv('only_today.csv', index=False)
love_chase.to_csv('love_chase.csv', index=False)
rapsodi.to_csv('rapsodi.csv', index=False)
himawari.to_csv('himawari.csv', index=False)
lantang.to_csv('lantang.csv', index=False)
